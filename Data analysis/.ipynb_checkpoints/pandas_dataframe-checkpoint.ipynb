# %%
import pandas as pd

# %%
df = pd.read_csv('acme.csv')
df.head()
# Out:
#    Unnamed: 0 month    market      acme
# 0           1  1/86 -0.061134  0.030160
# 1           2  2/86  0.008220 -0.165457
# 2           3  3/86 -0.007381  0.080137
# 3           4  4/86 -0.067561 -0.109917
# 4           5  5/86 -0.006238 -0.114853

# %%
df.index
# Out:
# RangeIndex(start=0, stop=60, step=1)

# %%
# Out:
#   File "<ipython-input-85-861caa0fbce5>", line 1
#     df.parse '(\d+)/(\d+)' IN month TO (m, y)
#                          ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  60 non-null     int64
#  1   month       60 non-null     object
#  2   market      60 non-null     float64
#  3   acme        60 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 2.0+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0     market       acme
# count   60.000000  60.000000  60.000000
# mean    30.500000  -0.051168  -0.068969
# std     17.464249   0.053629   0.111572
# min      1.000000  -0.262077  -0.284796
# 25%     15.750000  -0.079007  -0.133046
# 50%     30.500000  -0.044867  -0.089992
# 75%     45.250000  -0.011587  -0.031495
# max     60.000000   0.073396   0.242616

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'month', 'market', 'acme'], dtype='object')

# %%
df.size
# Out:
# 240

# %%
df.shape
# Out:
# (60, 4)

# %%
df.dtypes.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Unnamed: 0      int64
# month          object
# market        float64
# acme          float64
# dtype: object>

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# month          object
# market        float64
# acme          float64
# dtype: object

# %%
df.rename(columns={'Unnamed: 0' : 'list'}, inplace = True)

# %%
df.describe()
# Out:
#             list     market       acme
# count  60.000000  60.000000  60.000000
# mean   30.500000  -0.051168  -0.068969
# std    17.464249   0.053629   0.111572
# min     1.000000  -0.262077  -0.284796
# 25%    15.750000  -0.079007  -0.133046
# 50%    30.500000  -0.044867  -0.089992
# 75%    45.250000  -0.011587  -0.031495
# max    60.000000   0.073396   0.242616

# %%
df['market']
# Out:
# 0    -0.061134
# 1     0.008220
# 2    -0.007381
# 3    -0.067561
# 4    -0.006238
# 5    -0.044251
# 6    -0.112070
# 7     0.030226
# 8    -0.129556
# 9     0.001319
# 10   -0.033679
# 11   -0.072795
# 12    0.073396
# 13   -0.011618
# 14   -0.026852
# 15   -0.040356
# 16   -0.047539
# 17   -0.001732
# 18   -0.008899
# 19   -0.020837
# 20   -0.084811
# 21   -0.262077
# 22   -0.110167
# 23    0.034955
# 24    0.012688
# 25   -0.002170
# 26   -0.073462
# 27   -0.043419
# 28   -0.054730
# 29   -0.011755
# 30   -0.061718
# 31   -0.101710
# 32   -0.032705
# 33   -0.045334
# 34   -0.079288
# 35   -0.036233
# 36   -0.011494
# 37   -0.093729
# 38   -0.065215
# 39   -0.037113
# 40   -0.044399
# 41   -0.084412
# 42    0.003444
# 43   -0.056760
# 44   -0.078970
# 45   -0.105367
# 46   -0.038634
# 47   -0.043261
# 48   -0.139773
# 49   -0.059094
# 50   -0.057736
# 51   -0.102524
# 52    0.023881
# 53   -0.079116
# 54   -0.078965
# 55   -0.161359
# 56   -0.119376
# 57   -0.076008
# ...

# %%
df['market'].to_frame()
# Out:
#       market
# 0  -0.061134
# 1   0.008220
# 2  -0.007381
# 3  -0.067561
# 4  -0.006238
# 5  -0.044251
# 6  -0.112070
# 7   0.030226
# 8  -0.129556
# 9   0.001319
# 10 -0.033679
# 11 -0.072795
# 12  0.073396
# 13 -0.011618
# 14 -0.026852
# 15 -0.040356
# 16 -0.047539
# 17 -0.001732
# 18 -0.008899
# 19 -0.020837
# 20 -0.084811
# 21 -0.262077
# 22 -0.110167
# 23  0.034955
# 24  0.012688
# 25 -0.002170
# 26 -0.073462
# 27 -0.043419
# 28 -0.054730
# 29 -0.011755
# 30 -0.061718
# 31 -0.101710
# 32 -0.032705
# 33 -0.045334
# 34 -0.079288
# 35 -0.036233
# 36 -0.011494
# 37 -0.093729
# 38 -0.065215
# 39 -0.037113
# 40 -0.044399
# 41 -0.084412
# 42  0.003444
# 43 -0.056760
# 44 -0.078970
# 45 -0.105367
# 46 -0.038634
# 47 -0.043261
# 48 -0.139773
# 49 -0.059094
# 50 -0.057736
# 51 -0.102524
# 52  0.023881
# 53 -0.079116
# 54 -0.078965
# 55 -0.161359
# 56 -0.119376
# 57 -0.076008
# 58 -0.006444
# 59 -0.026401

# %%
#df.loc['1']

# %%
certificates_earned = pd.DataFrame({
    'Certificates': [8, 2, 5, 6],
    'Time (in months)': [16, 5, 9, 12]
})

certificates_earned.index = ['Tom', 'Kris', 'Ahmad', 'Beau']

print(certificates_earned.iloc[2])
# Out:
# Certificates        5
# Time (in months)    9
# Name: Ahmad, dtype: int64

# %% [markdown]
# <h3>conditional selection(boolean arrays)</h3>

# %%
df['list'] > 10
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51     True
# 52     True
# 53     True
# 54     True
# 55     True
# 56     True
# 57     True
# 58     True
# 59     True
# Name: list, dtype: bool

# %%
df.loc[df['list']> 10, 'list']
# Out:
# 10    11
# 11    12
# 12    13
# 13    14
# 14    15
# 15    16
# 16    17
# 17    18
# 18    19
# 19    20
# 20    21
# 21    22
# 22    23
# 23    24
# 24    25
# 25    26
# 26    27
# 27    28
# 28    29
# 29    30
# 30    31
# 31    32
# 32    33
# 33    34
# 34    35
# 35    36
# 36    37
# 37    38
# 38    39
# 39    40
# 40    41
# 41    42
# 42    43
# 43    44
# 44    45
# 45    46
# 46    47
# 47    48
# 48    49
# 49    50
# 50    51
# 51    52
# 52    53
# 53    54
# 54    55
# 55    56
# 56    57
# 57    58
# 58    59
# 59    60
# Name: list, dtype: int64

# %%
df.loc[df['list']> 10, ['list', 'market']]
# Out:
#     list    market
# 10    11 -0.033679
# 11    12 -0.072795
# 12    13  0.073396
# 13    14 -0.011618
# 14    15 -0.026852
# 15    16 -0.040356
# 16    17 -0.047539
# 17    18 -0.001732
# 18    19 -0.008899
# 19    20 -0.020837
# 20    21 -0.084811
# 21    22 -0.262077
# 22    23 -0.110167
# 23    24  0.034955
# 24    25  0.012688
# 25    26 -0.002170
# 26    27 -0.073462
# 27    28 -0.043419
# 28    29 -0.054730
# 29    30 -0.011755
# 30    31 -0.061718
# 31    32 -0.101710
# 32    33 -0.032705
# 33    34 -0.045334
# 34    35 -0.079288
# 35    36 -0.036233
# 36    37 -0.011494
# 37    38 -0.093729
# 38    39 -0.065215
# 39    40 -0.037113
# 40    41 -0.044399
# 41    42 -0.084412
# 42    43  0.003444
# 43    44 -0.056760
# 44    45 -0.078970
# 45    46 -0.105367
# 46    47 -0.038634
# 47    48 -0.043261
# 48    49 -0.139773
# 49    50 -0.059094
# 50    51 -0.057736
# 51    52 -0.102524
# 52    53  0.023881
# 53    54 -0.079116
# 54    55 -0.078965
# 55    56 -0.161359
# ...

# %% [markdown]
# <h3>Dropping stuff </h3>

# %%
df.drop(1)
# Out:
#     list  month    market      acme
# 0      1   1/86 -0.061134  0.030160
# 2      3   3/86 -0.007381  0.080137
# 3      4   4/86 -0.067561 -0.109917
# 4      5   5/86 -0.006238 -0.114853
# 5      6   6/86 -0.044251 -0.099254
# 6      7   7/86 -0.112070 -0.226846
# 7      8   8/86  0.030226  0.073445
# 8      9   9/86 -0.129556 -0.143064
# 9     10  10/86  0.001319  0.034776
# 10    11  11/86 -0.033679 -0.063375
# 11    12  12/86 -0.072795 -0.058735
# 12    13   1/87  0.073396  0.050214
# 13    14   2/87 -0.011618  0.111165
# 14    15   3/87 -0.026852 -0.127492
# 15    16   4/87 -0.040356  0.054522
# 16    17   5/87 -0.047539 -0.072918
# 17    18   6/87 -0.001732 -0.058979
# 18    19   7/87 -0.008899  0.236147
# 19    20   8/87 -0.020837 -0.094778
# 20    21   9/87 -0.084811 -0.135669
# 21    22  10/87 -0.262077 -0.284796
# 22    23  11/87 -0.110167 -0.171494
# 23    24  12/87  0.034955  0.242616
# 24    25   1/88  0.012688 -0.063518
# 25    26   2/88 -0.002170 -0.117677
# ...

# %%
df.drop([4,5])
# Out:
#     list  month    market      acme
# 0      1   1/86 -0.061134  0.030160
# 1      2   2/86  0.008220 -0.165457
# 2      3   3/86 -0.007381  0.080137
# 3      4   4/86 -0.067561 -0.109917
# 6      7   7/86 -0.112070 -0.226846
# 7      8   8/86  0.030226  0.073445
# 8      9   9/86 -0.129556 -0.143064
# 9     10  10/86  0.001319  0.034776
# 10    11  11/86 -0.033679 -0.063375
# 11    12  12/86 -0.072795 -0.058735
# 12    13   1/87  0.073396  0.050214
# 13    14   2/87 -0.011618  0.111165
# 14    15   3/87 -0.026852 -0.127492
# 15    16   4/87 -0.040356  0.054522
# 16    17   5/87 -0.047539 -0.072918
# 17    18   6/87 -0.001732 -0.058979
# 18    19   7/87 -0.008899  0.236147
# 19    20   8/87 -0.020837 -0.094778
# 20    21   9/87 -0.084811 -0.135669
# 21    22  10/87 -0.262077 -0.284796
# 22    23  11/87 -0.110167 -0.171494
# 23    24  12/87  0.034955  0.242616
# 24    25   1/88  0.012688 -0.063518
# 25    26   2/88 -0.002170 -0.117677
# 26    27   3/88 -0.073462  0.201674
# ...

# %%
df.drop(columns = [58,59])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-df68674ac2e4> in <module>
# ----> 1 df.drop(columns = [58,59])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df
#not changing actual dataframe.
# Out:
#     list  month    market      acme
# 0      1   1/86 -0.061134  0.030160
# 1      2   2/86  0.008220 -0.165457
# 2      3   3/86 -0.007381  0.080137
# 3      4   4/86 -0.067561 -0.109917
# 4      5   5/86 -0.006238 -0.114853
# 5      6   6/86 -0.044251 -0.099254
# 6      7   7/86 -0.112070 -0.226846
# 7      8   8/86  0.030226  0.073445
# 8      9   9/86 -0.129556 -0.143064
# 9     10  10/86  0.001319  0.034776
# 10    11  11/86 -0.033679 -0.063375
# 11    12  12/86 -0.072795 -0.058735
# 12    13   1/87  0.073396  0.050214
# 13    14   2/87 -0.011618  0.111165
# 14    15   3/87 -0.026852 -0.127492
# 15    16   4/87 -0.040356  0.054522
# 16    17   5/87 -0.047539 -0.072918
# 17    18   6/87 -0.001732 -0.058979
# 18    19   7/87 -0.008899  0.236147
# 19    20   8/87 -0.020837 -0.094778
# 20    21   9/87 -0.084811 -0.135669
# 21    22  10/87 -0.262077 -0.284796
# 22    23  11/87 -0.110167 -0.171494
# 23    24  12/87  0.034955  0.242616
# 24    25   1/88  0.012688 -0.063518
# ...

# %% [markdown]
# <h3>modifying the dataframe</h3>

# %%
langs = pd.Series([ 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi', 'french', 'irish', 'hindi'])

# %%
langs
# Out:
# 0     french
# 1      irish
# 2      hindi
# 3     french
# 4      irish
# 5      hindi
# 6     french
# 7      irish
# 8      hindi
# 9     french
# 10     irish
# 11     hindi
# 12    french
# 13     irish
# 14     hindi
# 15    french
# 16     irish
# 17     hindi
# 18    french
# 19     irish
# 20     hindi
# 21    french
# 22     irish
# 23     hindi
# 24    french
# 25     irish
# 26     hindi
# 27    french
# 28     irish
# 29     hindi
# 30    french
# 31     irish
# 32     hindi
# 33    french
# 34     irish
# 35     hindi
# 36    french
# 37     irish
# 38     hindi
# 39    french
# 40     irish
# 41     hindi
# 42    french
# 43     irish
# 44     hindi
# 45    french
# 46     irish
# 47     hindi
# 48    french
# 49     irish
# 50     hindi
# 51    french
# 52     irish
# 53     hindi
# 54    french
# 55     irish
# 56     hindi
# 57    french
# 58     irish
# 59     hindi
# dtype: object

# %%
df['Language'] = langs

# %%
df
# Out:
#     list  month    market      acme Language
# 0      1   1/86 -0.061134  0.030160   french
# 1      2   2/86  0.008220 -0.165457    irish
# 2      3   3/86 -0.007381  0.080137    hindi
# 3      4   4/86 -0.067561 -0.109917   french
# 4      5   5/86 -0.006238 -0.114853    irish
# 5      6   6/86 -0.044251 -0.099254    hindi
# 6      7   7/86 -0.112070 -0.226846   french
# 7      8   8/86  0.030226  0.073445    irish
# 8      9   9/86 -0.129556 -0.143064    hindi
# 9     10  10/86  0.001319  0.034776   french
# 10    11  11/86 -0.033679 -0.063375    irish
# 11    12  12/86 -0.072795 -0.058735    hindi
# 12    13   1/87  0.073396  0.050214   french
# 13    14   2/87 -0.011618  0.111165    irish
# 14    15   3/87 -0.026852 -0.127492    hindi
# 15    16   4/87 -0.040356  0.054522   french
# 16    17   5/87 -0.047539 -0.072918    irish
# 17    18   6/87 -0.001732 -0.058979    hindi
# 18    19   7/87 -0.008899  0.236147   french
# 19    20   8/87 -0.020837 -0.094778    irish
# ...

# %% [markdown]
# replacing vlaues per columns

# %%
df['Language'] = 'English'
df.head()
# Out:
#    list month    market      acme Language
# 0     1  1/86 -0.061134  0.030160  English
# 1     2  2/86  0.008220 -0.165457  English
# 2     3  3/86 -0.007381  0.080137  English
# 3     4  4/86 -0.067561 -0.109917  English
# 4     5  5/86 -0.006238 -0.114853  English

# %% [markdown]
# Renaming columns

# %%
df.rename(
    columns={
        'acme':'faults','market':'Market Values','list':'List'},
    index={
        1:'one', 2:'two'
    }
)
# Out:
#      List  month  Market Values    faults Language
# 0       1   1/86      -0.061134  0.030160  English
# one     2   2/86       0.008220 -0.165457  English
# two     3   3/86      -0.007381  0.080137  English
# 3       4   4/86      -0.067561 -0.109917  English
# 4       5   5/86      -0.006238 -0.114853  English
# 5       6   6/86      -0.044251 -0.099254  English
# 6       7   7/86      -0.112070 -0.226846  English
# 7       8   8/86       0.030226  0.073445  English
# 8       9   9/86      -0.129556 -0.143064  English
# 9      10  10/86       0.001319  0.034776  English
# 10     11  11/86      -0.033679 -0.063375  English
# 11     12  12/86      -0.072795 -0.058735  English
# 12     13   1/87       0.073396  0.050214  English
# 13     14   2/87      -0.011618  0.111165  English
# 14     15   3/87      -0.026852 -0.127492  English
# 15     16   4/87      -0.040356  0.054522  English
# 16     17   5/87      -0.047539 -0.072918  English
# ...

# %%
df.head()
#all the operations are immutable
# Out:
#    list month    market      acme Language
# 0     1  1/86 -0.061134  0.030160  English
# 1     2  2/86  0.008220 -0.165457  English
# 2     3  3/86 -0.007381  0.080137  English
# 3     4  4/86 -0.067561 -0.109917  English
# 4     5  5/86 -0.006238 -0.114853  English

# %%
import pandas as pd

certificates_earned = pd.DataFrame({
    'Certificates': [8, 2, 5, 6],
    'Time (in months)': [16, 5, 9, 12]
})
names = ['Tom', 'Kris', 'Ahmad', 'Beau']

certificates_earned.index = names
longest_streak = pd.Series([13, 11, 9, 7], index=names)
certificates_earned['Longest streak'] = longest_streak

print(certificates_earned)
# Out:
#        Certificates  Time (in months)  Longest streak
# Tom               8                16              13
# Kris              2                 5              11
# Ahmad             5                 9               9
# Beau              6                12               7

# %%
df['market per acme'] = df['market'] / df['acme']

# %%
mpa = df['market per acme']

# %%
df.head()
# Out:
#    list month    market      acme Language  market per acme
# 0     1  1/86 -0.061134  0.030160  English        -2.026989
# 1     2  2/86  0.008220 -0.165457  English        -0.049681
# 2     3  3/86 -0.007381  0.080137  English        -0.092105
# 3     4  4/86 -0.067561 -0.109917  English         0.614655
# 4     5  5/86 -0.006238 -0.114853  English         0.054313

# %% [markdown]
# <h3>statistical info</h3>

# %%
df.head()
# Out:
#    list month    market      acme Language  market per acme
# 0     1  1/86 -0.061134  0.030160  English        -2.026989
# 1     2  2/86  0.008220 -0.165457  English        -0.049681
# 2     3  3/86 -0.007381  0.080137  English        -0.092105
# 3     4  4/86 -0.067561 -0.109917  English         0.614655
# 4     5  5/86 -0.006238 -0.114853  English         0.054313

# %%
df
